# %%
people = {
    "first_name":["Duyen le","","NaN"],
    "last_name":"huu",
    "sdt":["0123","1234","3456"]
}
people2 = [{
    "first_name":"lê",
    "last_name":"duyen",
    "sdt":"0111223456"
}]

# %%
import pandas as pd
import random
import numpy as np

# %%
df = pd.DataFrame(people)
df2 = pd.DataFrame(people2)

# %%
df
# Out:
#   first_name last_name   sdt
# 0   Duyen le       huu  0123
# 1                  huu  1234
# 2        NaN       huu  3456

# %%
df.sdt
# Out:
# 0    0123
# 1    1234
# 2    3456
# Name: sdt, dtype: object

# %%
df['sdt']
# Out:
# 0    0123
# 1    1234
# 2    3456
# Name: sdt, dtype: object

# %%
df[['sdt','first_name']]
# Out:
#     sdt first_name
# 0  0123   Duyen le
# 1  1234
# 2  3456        NaN

# %%
df.columns
# Out:
# Index(['first_name', 'last_name', 'sdt'], dtype='object')

# %%
df.iloc[[0,1],1]
# Out:
# 0    huu
# 1    huu
# Name: last_name, dtype: object

# %%
df
# Out:
#   first_name last_name   sdt
# 0   Duyen le       huu  0123
# 1                  huu  1234
# 2        NaN       huu  3456

# %%
df.loc["sdt"]
# Out:
# 0    0123
# 2    3456
# Name: sdt, dtype: object

# %%
df.set_index('sdt',inplace=True)

# %%
df
# Out:
#      first_name last_name
# sdt
# 0123   Duyen le       huu
# 1234                  huu
# 3456        NaN       huu

# %%
df.index
# Out:
# Index(['0123', '1234', '3456'], dtype='object', name='sdt')

# %%
df.columns
# Out:
# Index(['first_name', 'last_name'], dtype='object')

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#     sdt first_name last_name
# 0  0123   Duyen le       huu
# 1  1234                  huu
# 2  3456        NaN       huu

# %%
df["first_name"] == "Duyen le"
# Out:
# 0     True
# 1    False
# 2    False
# Name: first_name, dtype: bool

# %%
filt = (df["first_name"] == "Duyen le") | (df["sdt"] == "3456")

# %%
df[filt]
# Out:
#     sdt first_name last_name
# 0  0123   Duyen le       huu
# 2  3456        NaN       huu

# %%
df.loc[~filt,"sdt"]
# Out:
# 1    1234
# Name: sdt, dtype: object

# %%
df.columns
# Out:
# Index(['sdt', 'first_name', 'last_name'], dtype='object')

# %%
df.columns = [x.upper() for x in df.columns]
df.columns = [x.lower() for x in df.columns]

df
# Out:
#     sdt first_name last_name
# 0  0123   Duyen le       huu
# 1  1234                  huu
# 2  3456        NaN       huu

# %%
df.columns = df.columns.str.replace(' ',"_")
df
# Out:
#     sdt first_name last_name
# 0  0123   Duyen le       huu
# 1  1234                  huu
# 2  3456        NaN       huu

# %%
df.rename(columns = {"fullname":"full_name","last_name":"middle_name"},inplace =True )

# %%
df
# Out:
#     sdt first_name middle_name
# 0  0123   Duyen le         huu
# 1  1234                    huu
# 2  3456        NaN         huu

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.rename(columns={"full_name":"first_name"},inplace = True)

# %%
df.loc[0,['full_name','middle_name','first_name']] = ["fullname","middle","first_name"]
df
# Out:
#     sdt  first_name middle_name full_name
# 0  0123  first_name      middle  fullname
# 1  1234                     huu       NaN
# 2  3456         NaN         huu       NaN

# %%
filt = (df['sdt'] > "1")

# %%
filt
# Out:
# 0    False
# 1     True
# 2     True
# Name: sdt, dtype: bool

# %%
df[filt]
# Out:
#     sdt first_name middle_name full_name
# 1  1234                    huu       NaN
# 2  3456        NaN         huu       NaN

# %%
df.loc[filt,"midde_name"] = "hihi"

# %%
df['first_name'] = df['first_name'].str.lower()

# %%
df
# Out:
#     sdt  first_name middle_name full_name midde_name
# 0  0123  first_name      middle  fullname        NaN
# 1  1234                     huu       NaN       hihi
# 2  3456         nan         huu       NaN       hihi

# %%
 df['sdt'].apply(len)
# Out:
# 0    4
# 1    4
# 2    4
# Name: sdt, dtype: int64

# %%
def upperString(first_name):
    return first_name.upper();

# %%
df['first_name'] = df['first_name'].apply(upperString)
df
# Out:
#     sdt  first_name middle_name full_name midde_name
# 0  0123  FIRST_NAME      middle  fullname        NaN
# 1  1234                     huu       NaN       hihi
# 2  3456         NAN         huu       NaN       hihi

# %%
df['full_name'] = df['midde_name'] = df['first_name'].apply(lambda x : x.upper())
df
# Out:
#     sdt  first_name middle_name   full_name  midde_name
# 0  0123  FIRST_NAME      middle  FIRST_NAME  FIRST_NAME
# 1  1234                     huu
# 2  3456         NAN         huu         NAN         NAN

# %%
# df.apply(len,axis ="columns")
# df.apply(len,axis ="rows")

# %%
len(df.columns)
# Out:
# 5

# %%
df.apply(pd.Series.min)
# Out:
# sdt            0123
# first_name
# middle_name     huu
# full_name
# midde_name
# dtype: object

# %%
df.applymap(len)
# Out:
#    sdt  first_name  middle_name  full_name  midde_name
# 0    4          10            6         10          10
# 1    4           0            3          0           0
# 2    4           3            3          3           3

# %%
df.apply(len)
# Out:
# sdt            3
# first_name     3
# middle_name    3
# full_name      3
# midde_name     3
# dtype: int64

# %%
df.applymap(str.lower)
# Out:
#     sdt  first_name middle_name   full_name  midde_name
# 0  0123  first_name      middle  first_name  first_name
# 1  1234                     huu
# 2  3456         nan         huu         nan         nan

# %%
# map thì chỉ thay đổi key có khai báo , ko khái báo sẽ thành NAN
# replace thì chỉ thay đổi key có khai báo , ko khái báo sẽ thành giá trị cũ
# df['first_name'] = df['first_name'].map({"first_name":"duyen1",'duyen le':"duyen2"})
df['first_name'] = df['first_name'].replace({"first_name":"duyen1",'duyen le':"duyen2"})

# %%
df['first_name'] = df["full_name"].apply(lambda x:x.lower())

# %%
df['full_name'] = df['full_name'].replace({"FIRST_NAME":"huu duyen","NAN":"Ha ha"})

# %%
df.drop(columns=["midde_name"],inplace=True)

# %%
df['full_name'].str.split(" ",expand=True)
# Out:
#      0      1
# 0  huu  duyen
# 1        None
# 2   Ha     ha

# %%
df[["first","last"]] = df['full_name'].str.split(" ",expand=True)

# %%
df = df.append({"full_name":"Ngoc Tram"},ignore_index=True)

# %%
df
# Out:
#     sdt  first_name middle_name  full_name first   last
# 0  0123  first_name      middle  huu duyen   huu  duyen
# 1  1234                     huu                    None
# 2  3456         nan         huu      Ha ha    Ha     ha
# 3   NaN         NaN         NaN  Ngoc Tram   NaN    NaN

# %%
df.loc[3,'first'],df.loc[3,'last'] =df.loc[3,'full_name'].split(" ")

# %%
people2 = {
    "full_name":["Duyen le 4","Duyen le 3","Duyen le 4"],
   
    "sdt":["0123","1234","3456"]
}
df2 = pd.DataFrame(people2)

# %%
df.append(df2,ignore_index=True,sort = True)
# Out:
#   first  first_name   full_name   last middle_name   sdt
# 0   huu  first_name   huu duyen  duyen      middle  0123
# 1                                 None         huu  1234
# 2    Ha         nan       Ha ha     ha         huu  3456
# 3  Ngoc         NaN   Ngoc Tram   Tram         NaN   NaN
# 4   NaN         NaN  Duyen le 4    NaN         NaN  0123
# 5   NaN         NaN  Duyen le 3    NaN         NaN  1234
# 6   NaN         NaN  Duyen le 4    NaN         NaN  3456

# %%
df
# Out:
#     sdt  first_name middle_name  full_name first   last
# 0  0123  first_name      middle  huu duyen   huu  duyen
# 1  1234                     huu                    None
# 2  3456         nan         huu      Ha ha    Ha     ha
# 3   NaN         NaN         NaN  Ngoc Tram  Ngoc   Tram

# %%
df.drop(index=3,inplace=True)
df
# Out:
#     sdt  first_name middle_name  full_name first   last
# 0  0123  first_name      middle  huu duyen   huu  duyen
# 1  1234                     huu                    None
# 2  3456         nan         huu      Ha ha    Ha     ha

# %%
df
# Out:
#     sdt  first_name middle_name  full_name first   last
# 0  0123  first_name      middle  huu duyen   huu  duyen
# 1  1234                     huu                    None
# 2  3456         nan         huu      Ha ha    Ha     ha

# %%
filt = (df["middle_name"]=="huu")
filt
# Out:
# 0    False
# 1     True
# 2     True
# Name: middle_name, dtype: bool

# %% [raw]
# df.drop(index=df[filt].index)

# %%
#df.loc[filt,"sdt"] =[random.randint(1,10000000) for k in df[filt].index ]
df
# Out:
#     sdt  first_name middle_name  full_name first   last
# 0  0123  first_name      middle  huu duyen   huu  duyen
# 1  1234                     huu                    None
# 2  3456         nan         huu      Ha ha    Ha     ha

# %%
[random.randint(1,10000000) for k in df[filt].index ]
# Out:
# [8610303, 3488444]

# %%
df['sdt']
# Out:
# 0    0123
# 1    1234
# 2    3456
# Name: sdt, dtype: object

# %%
df.sort_values(by="sdt",ascending = False)
# Out:
#     sdt  first_name middle_name  full_name first   last
# 2  3456         nan         huu      Ha ha    Ha     ha
# 1  1234                     huu                    None
# 0  0123  first_name      middle  huu duyen   huu  duyen

# %%
df.sort_values(by=["middle_name","sdt"],ascending = [True,False],inplace=True)

# %%
df

# %%
df.sort_index()

# %%
df['sdt'].sort_values()

# %%
df['sdt']
# Out:
# 0    0123
# 1    1234
# 2    3456
# Name: sdt, dtype: object

# %%
df.set_index('last')
# Out:
#         sdt  first_name middle_name  full_name first
# last
# duyen  0123  first_name      middle  huu duyen   huu
# NaN    1234                     huu
# ha     3456         nan         huu      Ha ha    Ha

# %%
df.reset_index()
# Out:
#    index   sdt  first_name middle_name  full_name first   last
# 0      0  0123  first_name      middle  huu duyen   huu  duyen
# 1      1  1234                     huu                    None
# 2      2  3456         nan         huu      Ha ha    Ha     ha

# %%
df
# Out:
#     sdt  first_name middle_name  full_name first   last
# 0  0123  first_name      middle  huu duyen   huu  duyen
# 1  1234                     huu                    None
# 2  3456         nan         huu      Ha ha    Ha     ha

# %%
df.loc['sdt']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\lehuu\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2890             try:
# -> 2891                 return self._engine.get_loc(casted_key)
#    2892             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'sdt'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-0379999ce1d9> in <module>
# ----> 1 df.loc['sdt']
#
# c:\users\lehuu\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# c:\users\lehuu\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# c:\users\lehuu\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# c:\users\lehuu\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3486             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3487         else:
# -> 3488             loc = self.index.get_loc(key)
#    3489
#    3490             if isinstance(loc, np.ndarray):
#
# c:\users\lehuu\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2891                 return self._engine.get_loc(casted_key)
#    2892             except KeyError as err:
# -> 2893                 raise KeyError(key) from err
#    2894
#    2895         if tolerance is not None:
#
# KeyError: 'sdt'
