# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv')

# %%
# row dau
df.head(10)
# row cuoi
df.tail(5)
# Out:
#        Respondent MainBranch Hobbyist  \
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
# shape use to count row and column
df.shape
# Out:
# (88883, 85)

# %%
# show column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
pd.set_option("display.max_columns",85)
pd.set_option("display.max_rows",85)

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv',index_col="Column")

# %%
schema_df.loc['MgrIdiot']
# Out:
# QuestionText    How confident are you that your manager knows ...
# Name: MgrIdiot, dtype: object

# %%
df['Hobbyist'].value_counts('Yes')
# Out:
# Yes    0.801694
# No     0.198306
# Name: Hobbyist, dtype: float64

# %%
df.loc[0:2,"Hobbyist":"Employment"]
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
schema_df.sort_index(ascending=False)
# Out:
#                                                              QuestionText
# Column
# YearsCodePro            How many years have you coded professionally (...
# YearsCode               Including any education, how many years have y...
# WorkWeekHrs              On average, how many hours per week do you work?
# WorkRemote                                How often do you work remotely?
# WorkPlan                          How structured or planned is your work?
# WorkLoc                                   Where would you prefer to work?
# WorkChallenge           Of these options, what are your greatest chall...
# WelcomeChange           Compared to last year, how welcome do you feel...
# WebFrameWorkedWith      Which of the following web frameworks have you...
# WebFrameDesireNextYear  Which of the following web frameworks have you...
# UnitTests               Does your company regularly employ unit tests ...
# UndergradMajor          What was your main or most important field of ...
# ...

# %%
filt = (df["ConvertedComp"] >=70000)

# %%
df.loc[filt,['Country','ConvertedComp','LanguageWorkedWith']]
# Out:
#               Country  ConvertedComp  \
# 5              Canada       366420.0
# 8         New Zealand        95179.0
# 12      United States        90000.0
# 15     United Kingdom       455352.0
# 21      United States       103000.0
# ...               ...            ...
# 88323   United States       180000.0
# 88324   United States      2000000.0
# 88325   United States       130000.0
# 88326         Finland        82488.0
# 88329     Netherlands       588012.0
#
#                                       LanguageWorkedWith
# 5                                             Java;R;SQL
# 8      Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 12     Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 15     Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 21     Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...                                                  ...
# 88323  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# ...

# %%
country = ['Canada','United States','New Zealand']
filt = (df['Country'].isin(country)) & (df["ConvertedComp"] >=700000)

# %%
df.loc[filt,['Country','ConvertedComp','LanguageWorkedWith']]
# Out:
#              Country  ConvertedComp  \
# 31     United States      1100000.0
# 57     United States      2000000.0
# 101    United States      2000000.0
# 155    United States       960000.0
# 164    United States      2000000.0
# ...              ...            ...
# 88164         Canada       732852.0
# 88264  United States      2000000.0
# 88266  United States      2000000.0
# 88321  United States      2000000.0
# 88324  United States      2000000.0
#
#                                       LanguageWorkedWith
# 31     Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 57                                           C#;Java;SQL
# 101                C#;HTML/CSS;JavaScript;SQL;TypeScript
# 155     Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;SQL
# 164    Bash/Shell/PowerShell;Go;HTML/CSS;Java;JavaScr...
# ...                                                  ...
# 88164  Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88264         HTML/CSS;Java;JavaScript;Kotlin;Python;SQL
# ...

# %%
filt = df['LanguageWorkedWith'].str.contains('Python',na =False)

# %%
df['LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 2                                                 HTML/CSS
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#                                ...
# 88878                        HTML/CSS;JavaScript;Other(s):
# 88879                                                  NaN
# 88880                                                  NaN
# 88881                                                  NaN
# 88882    Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# Name: LanguageWorkedWith, Length: 88883, dtype: object

# %%
df.loc[filt,'LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 88854    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88860      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 88865      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 88872             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88876                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
df.loc[filt,['Country','ConvertedComp','LanguageWorkedWith']]
# Out:
#                       Country  ConvertedComp  \
# 0              United Kingdom            NaN
# 1      Bosnia and Herzegovina            NaN
# 3               United States        61000.0
# 4                     Ukraine            NaN
# 7                       India            NaN
# ...                       ...            ...
# 88854          United Kingdom            NaN
# 88860                  Brazil            NaN
# 88865             Switzerland            NaN
# 88872          Czech Republic            NaN
# 88876                   Spain            NaN
#
#                                       LanguageWorkedWith
# 0                        HTML/CSS;Java;JavaScript;Python
# 1                                    C++;HTML/CSS;Python
# 3                                    C;C++;C#;Python;SQL
# 4            C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7      Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# ...                                                  ...
# ...

# %%
df.rename(columns={"Country":"quoc_gia","ConvertedComp":"luong","LanguageWorkedWith":"Ngôn ngữ"},inplace =True)
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df['Hobbyist'].map({"Yes1":False,"No":"hihi"})
# Out:
# 0         NaN
# 1        hihi
# 2         NaN
# 3        hihi
# 4         NaN
#          ...
# 88878     NaN
# 88879    hihi
# 88880    hihi
# 88881    hihi
# 88882     NaN
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['luong'].nlargest(10)
# Out:
# 57      2000000.0
# 101     2000000.0
# 164     2000000.0
# 434     2000000.0
# 450     2000000.0
# 489     2000000.0
# 537     2000000.0
# 767     2000000.0
# 786     2000000.0
# 1228    2000000.0
# Name: luong, dtype: float64

# %%
df.nsmallest(10,'luong')

# %%
df['luong'].nsmallest()

# %%
df.describe()
# Out:
#          Respondent     CompTotal         luong   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04  5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11  1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13  2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00  0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04  2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04  5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05  1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16  2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
df['luong'].count
# Out:
# <bound method Series.count of 0            NaN
# 1            NaN
# 2         8820.0
# 3        61000.0
# 4            NaN
#           ...
# 88878        NaN
# 88879        NaN
# 88880        NaN
# 88881        NaN
# 88882        NaN
# Name: luong, Length: 88883, dtype: float64>

# %%
df['SocialMedia'].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
df['SocialMedia'].value_counts(normalize =True) # thông kê thoe phần trăm xuất hiện
# Out:
# Reddit                      0.170233
# YouTube                     0.163791
# WhatsApp                    0.158071
# Facebook                    0.156069
# Twitter                     0.134988
# Instagram                   0.074150
# I don't use social media    0.065777
# LinkedIn                    0.053306
# WeChat 微信                   0.007899
# Snapchat                    0.007437
# VK ВКонта́кте               0.007141
# Weibo 新浪微博                  0.000663
# Youku Tudou 优酷              0.000249
# Hello                       0.000225
# Name: SocialMedia, dtype: float64

# %%
mediagrb = df.groupby(['SocialMedia'])

# %% [markdown]
# mediagrb.get_group()

# %%
mediagrb.get_group('Hello')
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 1387         1394                     I am a developer by profession      Yes
# 11773       11827                        I code primarily as a hobby      Yes
# 12670       12729                     I am a developer by profession      Yes
# 13074       13134             I am a student who is learning to code      Yes
# 13959       14024                     I am a developer by profession      Yes
# 15029       15105                     I am a developer by profession      Yes
# 20870       20986                        I code primarily as a hobby      Yes
# 26533       26688                     I am a developer by profession      Yes
# 30164       30345             I am a student who is learning to code      Yes
# 31101       31288  I am not primarily a developer, but I write co...      Yes
# 32408       32603             I am a student who is learning to code      Yes
# ...
